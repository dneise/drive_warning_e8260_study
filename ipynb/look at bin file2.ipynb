# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
names = """Time
Beschleunigungsistwert1
DrehmomentIstwert
DrehmomentSollwert
DrehmomentSollwertAdditiv
GeschwindigkeitsIstwert
GeschwindigkeitsSollwert
GeschwindigkeitsSollwertAdditiv
LageIstwert1
LageIstwert2
LageSollwert
MotorTemperatur
AplifierTemperatur
""".splitlines()
names
# Out:
# ['Time',
#  'Beschleunigungsistwert1',
#  'DrehmomentIstwert',
#  'DrehmomentSollwert',
#  'DrehmomentSollwertAdditiv',
#  'GeschwindigkeitsIstwert',
#  'GeschwindigkeitsSollwert',
#  'GeschwindigkeitsSollwertAdditiv',
#  'LageIstwert1',
#  'LageIstwert2',
#  'LageSollwert',
#  'MotorTemperatur',
#  'AplifierTemperatur']

# %%
df = pd.DataFrame(data=a.reshape(-1, len(names)), columns=names)

# %%
df.Time = pd.to_datetime(df.Time, unit='s')

# %%
df.set_index('Time', inplace=True)

# %%
df.columns
# Out:
# Index(['Beschleunigungsistwert1', 'DrehmomentIstwert', 'DrehmomentSollwert',
#        'DrehmomentSollwertAdditiv', 'GeschwindigkeitsIstwert',
#        'GeschwindigkeitsSollwert', 'GeschwindigkeitsSollwertAdditiv',
#        'LageIstwert1', 'LageIstwert2', 'LageSollwert', 'MotorTemperatur',
#        'AplifierTemperatur'],
#       dtype='object')

# %%
plt.plot(df.LageIstwert1,'.')
plt.plot(df.LageIstwert2,'.')
plt.plot(df.LageSollwert,'.')
plt.legend()

# %%
plt.plot(df.DrehmomentIstwert,'.')
plt.plot(df.DrehmomentSollwert,'.')
plt.legend()

# %%
df.DrehmomentIstwert.hist(bins=50)

# %%
plt.plot(df.MotorTemperatur,'.')

# %%
plt.plot(df.AplifierTemperatur,'.')

# %%
plt.plot(df.GeschwindigkeitsIstwert, '.')
plt.plot(df.GeschwindigkeitsSollwert,'.')

# %%
df.GeschwindigkeitsIstwert.hist(bins=50)

# %%
t = pd.Series(df.index)

# %%
t.diff().iloc[1:].describe()
# Out:
# count                      4905
# mean     0 days 00:00:00.074174
# std      0 days 00:00:00.008499
# min      0 days 00:00:00.046883
# 25%      0 days 00:00:00.062511
# 50%      0 days 00:00:00.078138
# 75%      0 days 00:00:00.078138
# max      0 days 00:00:00.109394
# Name: Time, dtype: object

# %%
bytes_per_day = (1/0.074174 * 3600 * 24 * 14)

# %%
mb_per_day = bytes_per_day / 1024**2

# %%
mb_per_day
# Out:
# 15.55214027994985
